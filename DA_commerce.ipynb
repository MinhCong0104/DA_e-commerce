# %%
import pandas as pd
import datetime as dt

# %%
file1 = 'List of Orders.csv' 
file2 = 'Order Details.csv'
file3 = 'Sales target.csv'
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)
df3 = pd.read_csv(file3)

# %% [markdown]
# 1. Clean 'List of Orders.csv'

# %%
print(df1.info())
print(df1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 560 entries, 0 to 559
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      500 non-null    object
#  1   Order Date    500 non-null    object
#  2   CustomerName  500 non-null    object
#  3   State         500 non-null    object
#  4   City          500 non-null    object
# dtypes: object(5)
# memory usage: 22.0+ KB
# None
#     Order ID  Order Date CustomerName           State       City
# 0    B-25601  01-04-2018       Bharat         Gujarat  Ahmedabad
# 1    B-25602  01-04-2018        Pearl     Maharashtra       Pune
# 2    B-25603  03-04-2018        Jahan  Madhya Pradesh     Bhopal
# 3    B-25604  03-04-2018       Divsha       Rajasthan     Jaipur
# 4    B-25605  05-04-2018      Kasheen     West Bengal    Kolkata
# ..       ...         ...          ...             ...        ...
# ...

# %%
df1 = df1.dropna()
df1
# Out:
#     Order ID  Order Date CustomerName              State       City
# 0    B-25601  01-04-2018       Bharat            Gujarat  Ahmedabad
# 1    B-25602  01-04-2018        Pearl        Maharashtra       Pune
# 2    B-25603  03-04-2018        Jahan     Madhya Pradesh     Bhopal
# 3    B-25604  03-04-2018       Divsha          Rajasthan     Jaipur
# 4    B-25605  05-04-2018      Kasheen        West Bengal    Kolkata
# ..       ...         ...          ...                ...        ...
# 495  B-26096  28-03-2019       Atharv        West Bengal    Kolkata
# 496  B-26097  28-03-2019         Vini          Karnataka  Bangalore
# 497  B-26098  29-03-2019        Pinky  Jammu and Kashmir    Kashmir
# 498  B-26099  30-03-2019       Bhishm        Maharashtra     Mumbai
# 499  B-26100  31-03-2019       Hitika     Madhya Pradesh     Indore
#
# [500 rows x 5 columns]

# %%
df1['Month of Order Date'] = df1['Order Date'].str.replace('-', '')
df1
# Out:
#     Order ID  Order Date CustomerName              State       City  \
# 0    B-25601  01-04-2018       Bharat            Gujarat  Ahmedabad
# 1    B-25602  01-04-2018        Pearl        Maharashtra       Pune
# 2    B-25603  03-04-2018        Jahan     Madhya Pradesh     Bhopal
# 3    B-25604  03-04-2018       Divsha          Rajasthan     Jaipur
# 4    B-25605  05-04-2018      Kasheen        West Bengal    Kolkata
# ..       ...         ...          ...                ...        ...
# 495  B-26096  28-03-2019       Atharv        West Bengal    Kolkata
# 496  B-26097  28-03-2019         Vini          Karnataka  Bangalore
# 497  B-26098  29-03-2019        Pinky  Jammu and Kashmir    Kashmir
# 498  B-26099  30-03-2019       Bhishm        Maharashtra     Mumbai
# 499  B-26100  31-03-2019       Hitika     Madhya Pradesh     Indore
#
#     Month of Order Date
# 0              01042018
# 1              01042018
# 2              03042018
# 3              03042018
# ...

# %%
df1['Month of Order Date'] = pd.to_datetime(df1['Month of Order Date'], format='%d%m%Y')
print(df1.info())
df1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Order ID             500 non-null    object
#  1   Order Date           500 non-null    object
#  2   CustomerName         500 non-null    object
#  3   State                500 non-null    object
#  4   City                 500 non-null    object
#  5   Month of Order Date  500 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), object(5)
# memory usage: 27.3+ KB
# None
#     Order ID  Order Date CustomerName              State       City  \
# 0    B-25601  01-04-2018       Bharat            Gujarat  Ahmedabad
# 1    B-25602  01-04-2018        Pearl        Maharashtra       Pune
# 2    B-25603  03-04-2018        Jahan     Madhya Pradesh     Bhopal
# 3    B-25604  03-04-2018       Divsha          Rajasthan     Jaipur
# ...

# %%
df1['Month of Order Date'] = df1['Month of Order Date'].dt.strftime('%b-%y')
print(df1.info())
df1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Order ID             500 non-null    object
#  1   Order Date           500 non-null    object
#  2   CustomerName         500 non-null    object
#  3   State                500 non-null    object
#  4   City                 500 non-null    object
#  5   Month of Order Date  500 non-null    object
# dtypes: object(6)
# memory usage: 27.3+ KB
# None
#     Order ID  Order Date CustomerName              State       City  \
# 0    B-25601  01-04-2018       Bharat            Gujarat  Ahmedabad
# 1    B-25602  01-04-2018        Pearl        Maharashtra       Pune
# 2    B-25603  03-04-2018        Jahan     Madhya Pradesh     Bhopal
# 3    B-25604  03-04-2018       Divsha          Rajasthan     Jaipur
# 4    B-25605  05-04-2018      Kasheen        West Bengal    Kolkata
# ...

# %%
#df1.to_csv('List of Orders - cleaned.csv', index=False)

# %% [markdown]
# 2. clean 'Order Details.csv'

# %%
print(df2.info())
print(df2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      1500 non-null   object
#  1   Amount        1500 non-null   float64
#  2   Profit        1500 non-null   float64
#  3   Quantity      1500 non-null   int64
#  4   Category      1500 non-null   object
#  5   Sub-Category  1500 non-null   object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 70.4+ KB
# None
#      Order ID  Amount  Profit  Quantity     Category      Sub-Category
# 0     B-25601  1275.0 -1148.0         7    Furniture         Bookcases
# 1     B-25601    66.0   -12.0         5     Clothing             Stole
# 2     B-25601     8.0    -2.0         3     Clothing       Hankerchief
# 3     B-25601    80.0   -56.0         4  Electronics  Electronic Games
# 4     B-25602   168.0  -111.0         2  Electronics            Phones
# ...

# %% [markdown]
# 3. clean 'Sales target.csv'

# %%
print(df3.info())
print(df3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Month of Order Date  36 non-null     object
#  1   Category             36 non-null     object
#  2   Target               36 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 992.0+ bytes
# None
#    Month of Order Date     Category   Target
# 0               Apr-18    Furniture  10400.0
# 1               May-18    Furniture  10500.0
# 2               Jun-18    Furniture  10600.0
# 3               Jul-18    Furniture  10800.0
# 4               Aug-18    Furniture  10900.0
# 5               Sep-18    Furniture  11000.0
# 6               Oct-18    Furniture  11100.0
# 7               Nov-18    Furniture  11300.0
# 8               Dec-18    Furniture  11400.0
# 9               Jan-19    Furniture  11500.0
# 10              Feb-19    Furniture  11600.0
# ...
